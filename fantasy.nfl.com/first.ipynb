# %%
from bs4 import BeautifulSoup
import mechanize
import cookielib
import html2text

# %%
br = mechanize.Browser()

# Cookie Jar
cj = cookielib.LWPCookieJar()
br.set_cookiejar(cj)

# %%
# Browser options
br.set_handle_equiv(True)
br.set_handle_gzip(True)
br.set_handle_redirect(True)
br.set_handle_referer(True)
br.set_handle_robots(False)
br.set_handle_refresh(mechanize._http.HTTPRefreshProcessor(), max_time=1)

# %%
br.addheaders = [('User-agent', 'Chrome')]

# The site we will navigate into, handling it's session
br.open('https://www.nfl.com/login')
# Out:
# <response_seek_wrapper at 0x9b59488L whose wrapped object = <closeable_response at 0x9b59388L whose fp = <mechanize._gzip.UnzipWrapper instance at 0x0000000009B592C8>>>

# %%
br.forms()
# Out:
# [<mechanize._form_controls.HTMLForm instance at 0x000000000A4CE048>,
#  <mechanize._form_controls.HTMLForm instance at 0x000000000A4CE648>]

# %%
# View available forms
for f in br.forms():
    print f
# Out:
# <GET https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D7 application/x-www-form-urlencoded>
# <POST https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D7 application/x-www-form-urlencoded
#   <TextControl(username=)>
#   <PasswordControl(password=)>
#   <SubmitButtonControl(<None>=) (readonly)>
#   <SubmitButtonControl(<None>=) (readonly)>>

# %%
# View available forms
for f in br.forms():
    print f

# Select the second (index one) form (the first form is a search query box)
br.select_form(nr=1)

# User credentials
br.form['fanProfileEmailUsername'] = 'bazlla'
br.form['fanProfilePassword'] = 'Mrafaq1'
logged_in = br.submit()   #submitting the login credentials

logincheck = logged_in.read()  #reading the page body that is redirected after successful login
print logincheck
# Out:
# <GET https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D6 application/x-www-form-urlencoded>
# <POST https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D6 application/x-www-form-urlencoded
#   <TextControl(username=)>
#   <PasswordControl(password=)>
#   <SubmitButtonControl(<None>=) (readonly)>
#   <SubmitButtonControl(<None>=) (readonly)>>
# ---------------------------------------------------------------------------
# ControlNotFoundError                      Traceback (most recent call last)
# <ipython-input-260-940e6ce1e35a> in <module>()
#       7
#       8 # User credentials
# ----> 9 br.form['fanProfileEmailUsername'] = 'bazlla'
#      10 br.form['fanProfilePassword'] = 'Mrafaq1'
#      11 logged_in = br.submit()   #submitting the login credentials
#
# ...

# %%
import cookielib 
import urllib2 
import mechanize 
import html2text
# Browser 
br = mechanize.Browser() 

# Enable cookie support for urllib2 
cookiejar = cookielib.LWPCookieJar() 
br.set_cookiejar( cookiejar ) 

# Browser options
br.set_handle_equiv(True)
br.set_handle_gzip(True)
br.set_handle_redirect(True)
br.set_handle_referer(True)
br.set_handle_robots(False)
br.set_handle_refresh(mechanize._http.HTTPRefreshProcessor(), max_time=1)

br.addheaders = [ ( 'User-agent', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1' ) ] 

# authenticate 
br.open('http://fantasy.nfl.com/league/4008988/history/2017/teamhome?teamId=6')
# Out:
# <response_seek_wrapper at 0x973f188L whose wrapped object = <closeable_response at 0x9769c48L whose fp = <mechanize._gzip.UnzipWrapper instance at 0x0000000009769AC8>>>

# %%
br.forms()
# Out:
# [<mechanize._form_controls.HTMLForm instance at 0x0000000009739288>,
#  <mechanize._form_controls.HTMLForm instance at 0x0000000009739688>]

# %%
print(br.forms()[1])
a=(br.forms()[1])
br.select_form(a)
# Out:
# <POST https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D6 application/x-www-form-urlencoded
#   <TextControl(username=)>
#   <PasswordControl(password=)>
#   <SubmitButtonControl(<None>=) (readonly)>
#   <SubmitButtonControl(<None>=) (readonly)>>
# ---------------------------------------------------------------------------
# FormNotFoundError                         Traceback (most recent call last)
# <ipython-input-248-89ad5e6913ce> in <module>()
#       1 print(br.forms()[1])
#       2 a=(br.forms()[1])
# ----> 3 br.select_form(a)
#
# C:\ProgramData\Anaconda2\lib\site-packages\mechanize\_mechanize.pyc in select_form(self, name, predicate, nr, **attrs)
#     667                     description.append('%s = %r' % (k, v))
#     668             description = ", ".join(description)
# --> 669             raise FormNotFoundError("no form matching " + description)
#     670
# ...

# %%
for f in br.forms():
    print f

# Select the second (index one) form (the first form is a search query box)
br.select_form(nr=1)

# User credentials
br.form['username'] = str('bazlla')
br.form['password'] = str('Mrafaq1')
logged_in = br.submit()   #submitting the login credentials

logincheck = logged_in.read()  #reading the page body that is redirected after successful login
print logincheck
# Out:
# <GET https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D6 application/x-www-form-urlencoded>
# <POST https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D6 application/x-www-form-urlencoded
#   <TextControl(username=)>
#   <PasswordControl(password=)>
#   <SubmitButtonControl(<None>=) (readonly)>
#   <SubmitButtonControl(<None>=) (readonly)>>
# <!doctype html>
# <html lang="en-US">
#     <head>
#
#         <script>
#             if ("performance" in window) {
#                 if ("mark" in performance) {
#                     performance.mark("render_ttfr_start");
#                 } else if ("now" in performance) {
#                     window.render_ttfr_start = performance.now();
#                 }
#             }
#         </script>
# ...

# %%
br.open("http://fantasy.nfl.com/league/4008988/history/2017/teamhome?teamId=6").get_data()
# Out:
# '<!doctype html>\n<html lang="en-US">\n    <head>\n        \n        <script>\n            if ("performance" in window) {\n                if ("mark" in performance) {\n                    performance.mark("render_ttfr_start");\n                } else if ("now" in performance) {\n                    window.render_ttfr_start = performance.now();\n                }\n            }\n        </script>\n        <script src="https://cdns.gigya.com/js/gigya.js?apiKey=3_JuHa5qkVIfY_KsNk1TuudSQT5Nif4axD-QXug1OgBmAgVieKA56umYvWPnoursaC" type="text/javascript"></script>\n        <link rel="dns-prefetch" href="https://static-wildcat.nfl.com" />\n        <link rel="preconnect" href="https://static-wildcat.nfl.com" crossorigin />\n\n        \n\n        \n            <link rel="preload" as="script" href="https://static-wildcat.nfl.com/bundles/manifest.945554c2.bundle.js" />\n            <link rel="preload" as="script" href="https://static-wildcat.nfl.com/bundles/www.nfl.60579d4c.bundle.js" />\n     
# ...

# %%
browser = mechanize.Browser()
browser.open(YOUR URL)
browser.select_form(nr = 0)
browser.form['username'] = USERNAME
browser.form['password'] = PASSWORD
browser.submit()

# %%
(br.response()).get_data()
# Out:
# '<!doctype html>\n<html lang="en-US">\n    <head>\n        \n        <script>\n            if ("performance" in window) {\n                if ("mark" in performance) {\n                    performance.mark("render_ttfr_start");\n                } else if ("now" in performance) {\n                    window.render_ttfr_start = performance.now();\n                }\n            }\n        </script>\n        <script src="https://cdns.gigya.com/js/gigya.js?apiKey=3_JuHa5qkVIfY_KsNk1TuudSQT5Nif4axD-QXug1OgBmAgVieKA56umYvWPnoursaC" type="text/javascript"></script>\n        <link rel="dns-prefetch" href="https://static-wildcat.nfl.com" />\n        <link rel="preconnect" href="https://static-wildcat.nfl.com" crossorigin />\n\n        \n\n        \n            <link rel="preload" as="script" href="https://static-wildcat.nfl.com/bundles/manifest.945554c2.bundle.js" />\n            <link rel="preload" as="script" href="https://static-wildcat.nfl.com/bundles/www.nfl.60579d4c.bundle.js" />\n     
# ...

# %%
soup = BeautifulSoup((br.response()).get_data())

# %%
br.viewing_html()
Mechanize.new.get("http://fantasy.nfl.com/league/4008988/history/2017/teamhome?teamId=7|").body.class
# Out:
#   File "<ipython-input-143-972eac4c32ae>", line 2
#     Mechanize.new.get("http://fantasy.nfl.com/league/4008988/history/2017/teamhome?teamId=7|").body.class
#                                                                                                         ^
# SyntaxError: invalid syntax

# %%
soup = BeautifulSoup(aa, "lxml")
soup
aa=(br.follow_link(nr=11))

# %%
response = br.response()
response.geturl()
# Out:
# 'https://www.nfl.com/login?s=fantasy&returnTo=http%3A%2F%2Ffantasy.nfl.com%2Fleague%2F4008988%2Fhistory%2F2017%2Fteamhome%3FteamId%3D7'

# %%
aaa=soup.find_all('div', class_="rsv-ae9db127")

# %%
aaa[9]
# Out:
# <div class="rsv-ae9db127" data-radium="true" data-reactid="186" style="align-items:center;flex-direction:column;-webkit-align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;-ms-flex-align:center;-webkit-box-align:center;-webkit-box-orient:vertical;-webkit-box-direction:normal;"><div data-radium="true" data-reactid="187" style="width:256px;"><div data-radium="true" data-reactid="188" style="padding-top:0;padding-right:15px;padding-bottom:24px;padding-left:15px;"><ul data-radium="true" data-reactid="189" style="font-size:14px;padding-top:0;padding-right:11px;padding-bottom:0;padding-left:11px;line-height:1.75;list-style-type:disc;font-family:Endzone Sans Medium, sans-serif;"><li data-reactid="190">NFL Fantasy Game Access</li><li data-reactid="191">Your teams' news first</li><li data-reactid="192">One place to manage all your online preferences</li><li data-reactid="193">Personalized NFL content and access to special offers</li></ul></div></div><div data-radium="tr
# ...

# %%
html = aa.read() #read and store the result html page
soup = BeautifulSoup(html)
soup #pass it for further parsing with beautiful soup

# %%
<form method="POST" data-radium="true" data-reactid="153">
    <div style="border-bottom:1px solid #CCCCCC;flex-grow:1;height:37px;margin-bottom:16px;margin-left:0;margin-right:0;margin-top:0;max-height:37px;width:100%;border-color:rgba(204, 204, 204, 0.6);-webkit-flex-grow:1;-ms-flex-positive:1;" data-radium="true" data-reactid="154">
        <h3 data-test-id="signin-section-header" style="border-bottom:2px solid #333333;color:#FFFFFF;display:inline;font-family:Endzone Sans Bold, sans-serif;font-size:20px;line-height:2.03;padding-bottom:4px;padding-left:0;padding-right:0;padding-top:0;text-transform:uppercase;border-color:#FFFFFF;" data-radium="true" data-reactid="155">Welcome to the NFL</h3></div>
    <span class="input username input-status-default" style="display:block;position:relative;margin-bottom:36px;" data-radium="true" data-reactid="156">
        <label for="fanProfileEmailUsername" style="color:#FFFFFF;display:block;font-size:12px;font-family:Endzone Sans Light, sans-serif;" data-radium="true" data-reactid="157"><!-- react-text: 158 -->Email or Username<!-- /react-text --><span style="color:#D50A0A;" data-radium="true" data-reactid="159">*</span></label>
    <div style="border:none;" data-radium="true" data-reactid="160">
        <input type="text" id="fanProfileEmailUsername" name="username" placeholder="nflfan@email.com" style="width:100%;padding-top:12px;padding-right:8px;padding-bottom:12px;padding-left:8px;line-height:1.25;height:40px;background-color:#FAFAFA;border:1px solid #7B7B7B;" value="" class="rmq-6b432759" data-radium="true" data-reactid="161"></div><!-- react-text: 162 --><!-- /react-text --></span>
    <span class="input password input-status-default" style="display:block;position:relative;margin-bottom:28px;" data-radium="true" data-reactid="163">
        <label for="fanProfilePassword" style="color:#FFFFFF;display:block;font-size:12px;font-family:Endzone Sans Light, sans-serif;" data-radium="true" data-reactid="164"><!-- react-text: 165 -->Password<!-- /react-text --><span style="color:#D50A0A;" data-radium="true" data-reactid="166">*</span></label>
        <div style="border:none;" data-radium="true" data-reactid="167">
        <input type="password" id="fanProfilePassword" name="password" placeholder="" style="width:100%;padding-top:12px;padding-right:8px;padding-bottom:12px;padding-left:8px;line-height:1.25;height:40px;background-color:#FAFAFA;border:1px solid #7B7B7B;" value="" class="rmq-6b432759" data-radium="true" data-reactid="168"></div><!-- react-text: 169 --><!-- /react-text --></span>
                    <div style="justify-content:space-between;align-items:center;font-family:Endzone Sans Light, sans-serif;color:#FFFFFF;margin-bottom:24px;-webkit-justify-content:space-between;-webkit-align-items:center;-ms-flex-pack:justify;-webkit-box-pack:justify;-ms-flex-align:center;-webkit-box-align:center;" class="rsv-ae9db127" data-radium="true" data-reactid="170">
                    <div data-radium="true" data-reactid="171"><button style="background-color:transparent;line-height:1;vertical-align:middle;" class="rsv-ae9db127" data-radium="true" data-reactid="172">
                    <div data-radium="true" data-reactid="173"><svg class="svg-check-circle" height="38" viewBox="0 0 24 24" width="38" x="0px" y="0px" data-reactid="174"><circle cx="12" cy="12" fill="#F2F2F2" r="10" data-reactid="175"></circle><path d="M0 0h24v24H0z" fill="none" data-reactid="176"></path>
                    <path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm-2 15l-5-5 1.41-1.41L10 14.17l7.59-7.59L19 8l-9 9z" style="fill:#F2F2F2;" data-reactid="177"></path></svg></div>
                    <div style="font-size:14px;margin-left:8px;flex:1 1 auto;height:40px;align-items:center;color:#FFFFFF;-webkit-flex:1 1 auto;-ms-flex:1 1 auto;-webkit-align-items:center;-ms-flex-align:center;-webkit-box-align:center;" class="rsv-ae9db127" data-radium="true" data-reactid="178">Remember Me</div></button></div>
                
                <div data-reactid="179"><a style="font-size:12px;line-height:2.5;text-transform:uppercase;text-decoration:none;color:rgba(255, 255, 255, 0.87);" href="/forgot-password" data-radium="true" data-reactid="180">Forgot password?</a></div></div><div style="text-align:center;" data-radium="true" data-reactid="181">
                    <button data-test-id="fanProfileSigninButton" style="background-color:#1B48E0;border-top:0;border-right:0;border-bottom:0;border-left:0;border-radius:0;color:#FFFFFF;cursor:pointer;display:inline-block;font-family:Endzone Sans Medium, sans-serif;font-size:14px;height:40px;letter-spacing:-0.3px;line-height:40px;opacity:1;overflow:hidden;padding-top:0;padding-right:32px;padding-bottom:0;padding-left:32px;position:relative;text-align:center;text-decoration:none;text-transform:uppercase;transition-delay:0ms;transition-duration:200ms;transition-property:all;transition-timing-function:ease-in-out;width:256px;margin-bottom:24px;-webkit-transition-delay:0ms;-webkit-transition-duration:200ms;-webkit-transition-property:all;-webkit-transition-timing-function:ease-in-out;" type="submit" data-radium="true" data-reactid="182"><!-- react-text: 183 -->Sign In<!-- /react-text -->
                        <div class="Ripple" style="height:0;left:0;top:0;width:0;background:rgba(0, 0, 0, 0.2);border-radius:100%;position:absolute;opacity:1;transform:scale(0);-webkit-transform:scale(0);-ms-transform:scale(0);" data-radium="true" data-reactid="184"></div></button></div>
                        
</form>
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-fafb7e5a6a04> in <module>()
# ----> 1 response.read()
#
# NameError: name 'response' is not defined

# %%
import csv
import re
import urllib
import requests
from bs4 import BeautifulSoup
import urllib3
url= "http://fantasy.nfl.com/league/4008988/history/2017/teamhome?teamId=7"
headers = {'User-Agent':'Mozilla/5.0'}
page = requests.get(url, headers=headers, verify=False)
data = page.content 
soup = BeautifulSoup(data, "html.parser")
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
second1 = soup.findAll('form')
second1
# Out:
# [<form class="rsv-ae9db127" data-radium="true" data-reactid="108" style="transition-duration:0.5s;transition-timing-function:cubic-bezier(0.215, 0.610, 0.355, 1.000);overflow:visible;position:relative;width:100%;-webkit-transition-duration:0.5s;-webkit-transition-timing-function:cubic-bezier(0.215, 0.610, 0.355, 1.000);"><div data-radium="true" data-reactid="109" style="background-color:#000000;color:#4A4A4A;display:block;left:0;position:absolute;width:100%;"><div data-radium="true" data-reactid="110" style="width:100%;"><div class="rmq-750e3755" data-radium="true" data-reactid="111" style="background-color:#013369;display:none;min-height:24px;position:absolute;top:48px;width:100%;z-index:10;"><div class="rmq-750e3755" data-radium="true" data-reactid="112" style="box-shadow:rgba(0, 0, 0, 0.47) 0px 2px 2px 0px;height:12px;width:100%;"></div></div><ul class="rmq-86b74097" data-radium="true" data-reactid="113" style="min-height:0;left:0;list-style-type:none;margin-top:0;margin-right:0;m
# ...

# %%
import cookielib
import urllib
import urllib2

# %%
# Store the cookies and create an opener that will hold them
cj = cookielib.CookieJar()
opener = urllib2.build_opener(urllib2.HTTPCookieProcessor(cj))

# %%
# Add our headers
opener.addheaders = [('User-agent', 'RedditTesting')]

# Install our opener (note that this changes the global opener to the one
# we just made, but you can also just call opener.open() if you want)
urllib2.install_opener(opener)

# %%
# The action/ target from the form
authentication_url = 'http://fantasy.nfl.com/league/4008988/history/2017/teamhome?teamId=7'

# %%
# Input parameters we are going to send
payload = {
  'op': 'login-main',
  'user': '<username>',
  'passwd': '<password>'
  }

# %%
import cookielib
import urllib
import urllib2


# Store the cookies and create an opener that will hold them
cj = cookielib.CookieJar()
opener = urllib2.build_opener(urllib2.HTTPCookieProcessor(cj))

# Add our headers
opener.addheaders = [('User-agent', 'RedditTesting')]

# Install our opener (note that this changes the global opener to the one
# we just made, but you can also just call opener.open() if you want)
urllib2.install_opener(opener)

# The action/ target from the form
authentication_url = 'https://www.nfl.com/login'

# Input parameters we are going to send
payload = {
  'username': 'bazlla',
  'password': 'Mrafaq1'
  }

# Use urllib to encode the payload
data = urllib.urlencode(payload)

# Build our Request object (supplying 'data' makes it a POST)
req = urllib2.Request(authentication_url, data)

# Make the request and read the response
resp = urllib2.urlopen(req)
contents = resp.read()

# %%
resp.url
# Out:
# 'https://www.nfl.com/login'

# %%
import requests, lxml.html
s = requests.session()

### Here, we're getting the login page and then grabbing hidden form
### fields.  We're probably also getting several session cookies too.
login = s.get('https://www.nfl.com/login')
login_html = lxml.html.fromstring(login.text)

# %%
# Out:
# <Element html at 0x9a639a8>

# %%
hidden_inputs = login_html.xpath(r'//form//input')

# %%
hidden_inputs
# Out:
# [<InputElement 9a63db8 name='username' type='text'>,
#  <InputElement 9a63e08 name='password' type='password'>]

# %%
form = {x.attrib["name"]: x.attrib["value"] for x in hidden_inputs}
form
# Out:
# {'password': '', 'username': ''}

# %%
form['username'] = 'Mrafaq1' # Enter an email here.  Not mine.
form['password'] = 'bazlla' # I'm definitely not telling you my password.
response = s.post('https://www.nfl.com/login', data=form)

### How can we tell that we logged in?  Well, these worked for me:
response.url
# Out:
# u'https://www.nfl.com/login'

# %%
'Stephen' in response.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-291-90f99aaf3773> in <module>()
# ----> 1 'Stephen' in response.text
#
# C:\ProgramData\Anaconda2\lib\site-packages\mechanize\_response.pyc in __getattr__(self, name)
#     104         wrapped = self.__dict__.get("wrapped")
#     105         if wrapped:
# --> 106             return getattr(wrapped, name)
#     107
#     108         return getattr(self.__class__, name)
#
# AttributeError: closeable_response instance has no attribute 'text'
