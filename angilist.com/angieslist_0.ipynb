# %%
from openpyxl import load_workbook

from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import csv
from random import randint
import json, io

from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
from selenium.webdriver.common.action_chains import ActionChains

import urllib
import urllib3
import requests
import json, io
from bs4 import BeautifulSoup
urllib3.disable_warnings()
header = {'User-Agent':'Mozilla/6.0'}


chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--user-agent="Mozilla/6.0')
chrome_options.add_argument("user-data-dir=selenium")
driver = webdriver.Chrome(chrome_options=chrome_options, executable_path=r'chromedriver.exe')


# cookies = json.load(open('cookiesdict.txt'))
# for cookie in cookies:
#     driver.add_cookie(cookie)

# %%
link='https://www.angieslist.com/companylist/us/ny/east-elmhurst/1-best-construction-reviews-8909651.htm'
driver.get(link)

# %%
# Out:
# <html><head>\n<title>Access Denied</title>\n</head><body>\n<h1>Access Denied</h1>\n \nYou don't have permission to access "http://www.angieslist.com/companylist/us/ny/east-elmhurst/1-best-construction-reviews-8909651.htm" on this server.<p>\nReference #18.6ef91402.1542503511.1812c3a8\n</p></body>\n</html>\n

# %%
so1=BeautifulSoup(driver.page_source, 'lxml')

# %%
categories0=so1.find_all(class_="geocat-cities-list__container geocat-cities-list__container--static-top-categories")[0].find_all('a')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-5ffe6d2b6b29> in <module>()
# ----> 1 categories0=so1.find_all(class_="geocat-cities-list__container geocat-cities-list__container--static-top-categories")[0].find_all('a')
#
# IndexError: list index out of range

# %%
categoriessave1=[]

for i in range(0,len(categories0)):
    categoriessave0=[]
    categoriessave0.append('https://www.angieslist.com'+categories0[i].get('href'))
    categoriessave0.append(categories0[i].text)
    print 'https://www.angieslist.com'+categories0[i].get('href')
    print categories0[i].text
    categoriessave1.append(categoriessave0)
# Out:
# https://www.angieslist.com/companylist/air-duct-cleaning.htm
# Air Duct Cleaning
# https://www.angieslist.com/companylist/appliance-repair.htm
# Appliance Repair
# https://www.angieslist.com/companylist/architects.htm
# Architect
# https://www.angieslist.com/companylist/driveways.htm
# Asphalt Driveway
# https://www.angieslist.com/companylist/awnings.htm
# Awnings
# https://www.angieslist.com/companylist/remodeling-basements.htm
# Basement Remodeling
# https://www.angieslist.com/companylist/basement-waterproofing.htm
# Basement Waterproofing
# https://www.angieslist.com/companylist/kitchen-and-bath-remodeling.htm
# Bathroom & Kitchen Remodeling
# https://www.angieslist.com/companylist/bathtub-refinishing.htm
# Bathtub Refinishing
# https://www.angieslist.com/companylist/cabinet-refinishing.htm
# Cabinet Refacing
# https://www.angieslist.com/companylist/carpet-cleaning.htm
# Carpet Cleaners
# https://www.angieslist.com/companylist/carpet.htm
# Carpet Installation
# ...

# %%
categoriessave2=[]

# %%
for q in range(0,len(categoriessave1)):
    driver.get(categoriessave1[q][0])
    sleep(3)

    so2=BeautifulSoup(driver.page_source, 'lxml')
    
    categories0=so2.find_all(class_="geocat-cities-list__container geocat-cities-list__container--major-markets geocat-major-markets-processed")[0].find_all('a')


    for i in range(0,len(categories0)):
        categoriessave0=[]
        categoriessave0.append(categoriessave1[q][1])
        categoriessave0.append(categories0[i].get('href'))
        categoriessave0.append(categories0[i].text)
        categoriessave2.append(categoriessave0)

# %%
globalsave=[]

# %%
list0=[]
wb = load_workbook(filename='page_links.xlsx', read_only=True)
ws = wb['Sheet']
for row in ws.rows:
    list00=[]
    for kl in range(len(row)):
        
        list00.append(row[kl].value)
    list0.append(list00)

# %%
# len(categoriessave2)
len(list0)
# Out:
# 5696

# %%
links_rofing=list0
# Out:
# 5696

# %%
z
# Out:
# 5299

# %%
for z in range(5299,len(links_rofing)):
    m=0
    while True:
        driver.get(links_rofing[z][1]+'?page='+str(m))

        sleep(3)
        if driver.current_url==links_rofing[z][1]:
            break
        m=m+1

        so3=BeautifulSoup(driver.page_source, 'lxml')

        list__sp=so3.find_all('ul',class_="geocat-full-sp-list__sp-list")

        for k in range(len(list__sp)):
            comp=list__sp[k].find_all('a')
            for u in range(len(comp)):
                localsave=[]  
                localsave.append(comp[u].get('href'))
                localsave.append(links_rofing[z][0])
                localsave.append(links_rofing[z][2])
                globalsave.append(localsave)
                print(len(globalsave))
# Out:
# 73012
# 73013
# 73014
# 73015
# 73016
# 73017
# 73018
# 73019
# 73020
# 73021
# 73022
# 73023
# 73024
# 73025
# 73026
# 73027
# 73028
# 73029
# 73030
# 73031
# 73032
# 73033
# 73034
# 73035
# 73036
# 73037
# 73038
# 73039
# 73040
# 73041
# 73042
# 73043
# 73044
# 73045
# 73046
# 73047
# 73048
# 73049
# 73050
# 73051
# 73052
# 73053
# 73054
# 73055
# 73056
# 73057
# 73058
# 73059
# 73060
# 73061
# 73062
# 73063
# 73064
# 73065
# 73066
# 73067
# 73068
# 73069
# 73070
# 73071
# 73072
# 73073
# 73074
# 73075
# 73076
# 73077
# 73078
# 73079
# 73080
# 73081
# 73082
# 73083
# 73084
# 73085
# 73086
# 73087
# 73088
# 73089
# 73090
# 73091
# 73092
# 73093
# 73094
# 73095
# 73096
# 73097
# 73098
# 73099
# 73100
# 73101
# 73102
# 73103
# 73104
# 73105
# 73106
# 73107
# 73108
# 73109
# 73110
# 73111
# 73112
# 73113
# 73114
# 73115
# 73116
# 73117
# 73118
# 73119
# 73120
# 73121
# 73122
# 73123
# 73124
# 73125
# 73126
# 73127
# 73128
# 73129
# 73130
# 73131
# 73132
# 73133
# 73134
# 73135
# 73136
# ...

# %%
# Out:
# u'https://www.angieslist.com/companylist/miami/home-improvement.htm?page=0'

# %%
categoriessave1
import warnings
from openpyxl import Workbook

wb = Workbook(write_only=True)
ws = wb.create_sheet()

# now we'll fill it with 100 rows x 200 columns
for irow in globalsave:
    ws.append(irow)
# save the file
wb.save('save_links_0_100.xlsx')
