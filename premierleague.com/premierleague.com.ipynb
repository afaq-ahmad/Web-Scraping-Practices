# %%
from openpyxl import load_workbook

from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import csv
from random import randint
import json, io

from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
from selenium.webdriver.common.action_chains import ActionChains

import urllib
import urllib3
import requests
import json, io
from bs4 import BeautifulSoup
urllib3.disable_warnings()
header = {'User-Agent':'Mozilla/5.0'}


chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--user-agent="Mozilla/5.0')
chrome_options.add_argument("user-data-dir=selenium")
driver = webdriver.Chrome(chrome_options=chrome_options, executable_path=r'/Users/Name/Downloads/Compressed/chromedrives/chromedriver.exe')


# cookies = json.load(open('cookiesdict.txt'))
# for cookie in cookies:
#     driver.add_cookie(cookie)
    

driver.get('https://www.premierleague.com/fixtures')

# %%
for i in range(0,10):
    driver.execute_script("window.scrollTo(0, 500000)")
    sleep(10)

# %%
so1=BeautifulSoup(driver.page_source, 'lxml')

# %%
quickView0=so1.find_all(class_="btn quickView")
for i in range(0,len(quickView0)):
    datast=['-']*11
    try:
        quickView=quickView0[i]
        afaq=quickView.get('data-ui-args')
        json_acceptable_string = afaq.replace("'", "\"")
        d = json.loads(json_acceptable_string)

        ground=d['ground']['name']
        #print ground
        datast[0]=ground
        city=d['ground']['city']
        #print city
        datast[1]=city

        kickOffTime=d['kickOffTime']
        #print kickOffTime
        datast[2]=kickOffTime

        matchDate=d['matchDate']
        #print matchDate
        datast[3]=matchDate
        
        team1_name=d['teams'][0]['team']['name']
        #print team1_name
        datast[4]=team1_name
        team1_shortName=d['teams'][0]['team']['shortName']
        #print team1_shortName
        datast[5]=team1_shortName
        team1_link=d['teams'][0]['url']
        #print team1_link
        datast[6]=team1_link
        
        team2_name=d['teams'][1]['team']['name']
        #print team2_name
        datast[7]=team2_name
        team2_shortName=d['teams'][1]['team']['shortName']
        #print team2_shortName
        datast[8]=team2_shortName
        team2_link=d['teams'][1]['url']
        #print team2_link
        datast[9]=team2_link
        
        match_details_link=d['url']
        #print match_details_link
        datast[10]=match_details_link
        #print '--------'
    except:
        #print '++++++++++++++++++'
        try:
            quickView=quickView0[i]
            afaq=quickView.get('data-ui-args')
            json_acceptable_string = afaq.replace("'", "\"")

            ground=json_acceptable_string.split('ground')[1].split('name')[1].split(':')[1].replace('"','').split(',')[0]
            #print ground
            datast[0]=ground
            city=json_acceptable_string.split('ground')[1].split('name')[1].split(':')[2].replace('"','').split(',')[0]
            #print city
            datast[1]=city

            kickOffTime0=json_acceptable_string.split('kickOffTime')[1].split(',')[0].replace('"','')
            kickOffTime=kickOffTime0[1:len(kickOffTime0)]
            #print kickOffTime
            datast[2]=kickOffTime

            matchDate=json_acceptable_string.split('matchDate')[1].split(':')[1].replace('"','').split(',')[0]
            #print matchDate
            datast[3]=matchDate



            team1_name=json_acceptable_string.split('"club":{"name":')[1].split(',')[0].replace('"','')
            #print team1_name
            datast[4]=team1_name
            team1_shortName=json_acceptable_string.split('"club":{"name":')[1].split(',')[1].split(':')[1].replace('"','')
            #print team1_shortName
            datast[5]=team1_shortName

            team1_link=json_acceptable_string.split('url":"')[1].split('}')[0].replace('"','')
            #print team1_link
            datast[6]=team1_link

            team2_name=json_acceptable_string.split('"club":{"name":')[2].split(',')[0].replace('"','')
            #print team2_name
            datast[7]=team2_name
            team2_shortName=json_acceptable_string.split('"club":{"name":')[2].split(',')[1].split(':')[1].replace('"','')
            #print team2_shortName
            datast[8]=team2_shortName
            
            team2_link=json_acceptable_string.split('url":"')[2].split('}')[0].replace('"','')
            #print team2_link
            datast[9]=team2_link
            
            match_details_link=json_acceptable_string.split('url')[-1].replace(':','').replace('"','').replace('}','')
            #print match_details_link
            datast[10]=match_details_link
        except Exception as e:
            #print '++++++++++++++++++'
            error_saving.append(i)
    print i,datast
    savedata1.append(datast)
# Out:
# 0 [u'King Power Stadium', u'Leicester', u'16:30', u'Saturday 1 September 2018', u'Leicester City', u'Leicester', u'//www.premierleague.com/clubs/26/Leicester-City/overview', u'Liverpool', u'Liverpool', u'//www.premierleague.com/clubs/10/Liverpool/overview', u'//www.premierleague.com/match/38344']
# 1 [u'Amex Stadium', u'Falmer', u'19:00', u'Saturday 1 September 2018', u'Brighton and Hove Albion', u'Brighton', u'//www.premierleague.com/clubs/131/Brighton-and-Hove Albion/overview', u'Fulham', u'Fulham', u'//www.premierleague.com/clubs/34/Fulham/overview', u'//www.premierleague.com/match/38338']
# 2 [u'Stamford Bridge', u'London', u'19:00', u'Saturday 1 September 2018', u'Chelsea', u'Chelsea', u'//www.premierleague.com/clubs/4/Chelsea/overview', u'AFC Bournemouth', u'AFC Bournemouth', u'//www.premierleague.com/clubs/127/Bournemouth/overview', u'//www.premierleague.com/match/38341']
# ...

# %%
len(error_saving)
# Out:
# 0

# %%
import warnings
from openpyxl import Workbook

wb = Workbook(write_only=True)
ws = wb.create_sheet()

# now we'll fill it with 100 rows x 200 columns
for irow in savedata1:
    ws.append(irow)
# save the file
wb.save('premierleague_fixtures.xlsx')

# %%
from openpyxl import load_workbook
import warnings
from openpyxl import Workbook

# %%
list0=[]
wb = load_workbook(filename='premierleague_fixtures.xlsx', read_only=True)
ws = wb['Sheet']
for row in ws.rows:
#       list0.append([row[0].value,row[1].value,row[2].value,row[3].value,row[4].value,row[5].value,row[6].value,row[7].value,row[8].value,row[9].value,row[10].value,row[11].value,row[12].value,row[13].value,row[14].value,row[15].value,row[16].value,row[17].value,row[18].value,row[19].value,row[20].value,row[21].value,row[22].value,row[23].value,row[24].value,row[25].value,row[26].value,row[27].value,row[28].value,row[29].value,row[30].value,row[31].value,row[32].value,row[33].value,row[34].value,row[35].value,row[36].value,row[37].value,row[38].value,row[39].value])
    list00=[]
    for kl in range(len(row)):
        
        list00.append(row[kl].value)
    list0.append(list00)

# %%
list0[0]
# Out:
# [u'Ground',
#  u'City',
#  u'Kick of time',
#  u'Match date',
#  u'Home team name',
#  u'Home team shortname',
#  u'Home team info url',
#  u'Awayteam name',
#  u'Awayteam shortname',
#  u'Awayteam info url',
#  u'Match info url']

# %%
list0[0][5]  #.replace(' ','-')
# Out:
# u'Home team shortname'

# %%
for i in range(1,len(list0)):
    data=['-']*2
    if len(list0[i][3].split()[-3])==2:
        fullnameurl='https://www.theguardian.com/football/live/'+list0[i][3].split()[-1]+'/'+list0[i][3].split()[-2]+'/'+list0[i][3].split()[-3]+'/'+list0[i][4].replace(' ','-')+'-v-'+list0[i][7].replace(' ','-')+'-premier-league-live'
        print fullnameurl.lower()
        data[0]=fullnameurl.lower()
        
        shortname='https://www.theguardian.com/football/live/'+list0[i][3].split()[-1]+'/'+list0[i][3].split()[-2]+'/'+list0[i][3].split()[-3]+'/'+list0[i][5].replace(' ','-')+'-v-'+list0[i][8].replace(' ','-')+'-premier-league-live'
        print shortname.lower() 
        data[1]=shortname.lower()
        
    if len(list0[i][3].split()[-3])==1:
        fullnameurl='https://www.theguardian.com/football/live/'+list0[i][3].split()[-1]+'/'+list0[i][3].split()[-2]+'/'+'0'+list0[i][3].split()[-3]+'/'+list0[i][4].replace(' ','-')+'-v-'+list0[i][7].replace(' ','-')+'-premier-league-live'
        print fullnameurl.lower()
        data[0]=fullnameurl.lower()
        
        shortname='https://www.theguardian.com/football/live/'+list0[i][3].split()[-1]+'/'+list0[i][3].split()[-2]+'/'+'0'+list0[i][3].split()[-3]+'/'+list0[i][5].replace(' ','-')+'-v-'+list0[i][8].replace(' ','-')+'-premier-league-live'
        print shortname.lower()
        data[1]=shortname.lower()
    list0[i]=list0[i]+data
# Out:
# https://www.theguardian.com/football/live/2018/september/01/leicester-city-v-liverpool-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/leicester-v-liverpool-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/brighton-and-hove-albion-v-fulham-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/brighton-v-fulham-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/chelsea-v-afc-bournemouth-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/chelsea-v-afc-bournemouth-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/crystal-palace-v-southampton-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/crystal-palace-v-southampton-premier-league-live
# https://www.theguardian.com/football/live/2018/september/01/everton-v-huddersfield-town-premier-league-live
# ...

# %%
import warnings
from openpyxl import Workbook

wb = Workbook(write_only=True)
ws = wb.create_sheet()

# now we'll fill it with 100 rows x 200 columns
for irow in list0:
    ws.append(irow)
# save the file
wb.save('premierleague_fixtures_urls.xlsx')
