# %%
'''
Devolper Name: AFAQ AHMAD
Fiverr: https://www.fiverr.com/mrafaq1
Whatssapp: +92-335695635
Email:afaq.ahmad100@gmail.com
'''

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import csv
from random import randint
import json, io

from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException

driver = webdriver.Chrome(executable_path=r'/Users/Name/Downloads/Compressed/chromedrives/chromedriver.exe')

# %%
driver.get("https://findadentist.ada.org/search-results?specialty=&name=&address=33704&practiceFocus=&patientType=&gender=&distance=&photo=&openOnSaturday=")
time.sleep(10)

# %%
s = BeautifulSoup(driver.page_source, 'lxml')

# %%
dentist_selector=s.find_all("li", class_="dentist-list__item")
for i in range(0,len(dentist_selector)):
    link0=dentist_selector[i].find_all("a",href=True)
    list1.append(link0[1].attrs['href'])
len(list1)

# %%
from collections import OrderedDict
list_sor=list(OrderedDict.fromkeys(list1))
list_sor
list3=['-','-','-','-','-','-','-']

# %%
for i in range(423,len(list_sor)):
    print(i)
    data=['-']*13
    url00='https://findadentist.ada.org/'
    fullurl=url00+list_sor[i]
    driver.get(fullurl)
    time.sleep(10)
    
    s = BeautifulSoup(driver.page_source, 'lxml')
    data[12]=fullurl

    name0=s.find('div', class_="name")
    name=name0.find('h1')
    name=(name.text).encode('ascii', 'ignore')
    data[0]=name
    specialties0=s.find('div', class_="specialties")
    specialties=(specialties0.text).replace("\n","")
    data[1]=specialties


    details0=s.find_all('dl', class_="definition-list--last")
    linkdetails=details0[0].find_all('a', href=True)



    for m in range(0,len(linkdetails)):
        aaa=linkdetails[m].text
        if 'www' in aaa:
            website=aaa
            data[4]=website
        if '@' in aaa:
            email=aaa
            data[3]=(email.replace("\n","")).replace("  ","")
        
        phone=phone_number=re.findall("\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4}", aaa, flags=re.IGNORECASE)
        if len(phone)>0:
            data[2]=phone[0]

    detaa=s.find_all('div', class_="dentist-details__item")
    Address0=detaa[1].find('dd')
    Address1=((((((Address0.text).replace("\t","")).replace("\n","")).replace("  ","")).replace(","," ")).encode('ascii', 'ignore'))
    Address2=Address1.split()
    zipcode=Address2[-1]
    data[5]=zipcode
    Region=Address2[-2]
    data[6]=Region
    city=' '.join(map(str, Address2[-4:-2]))
    data[7]=city
    houseAddress=' '.join(map(str, Address2[0:-4]))
    data[8]=houseAddress

    details00=s.find_all('section', class_='dentist-details__description')
    details01=details00[0].find_all('dl', class_="definition-list--last")
    special_details=details01[0].find_all('dd')
    headings0=details01[0].find_all('dt')

    for n in range(0,len(headings0)):
        if headings0[n].text=='Gender':
            Gender=special_details[n].text
            Gender=(Gender.replace("\n","")).replace("  ","")
            data[9]=Gender

        if headings0[n].text=='Specialties':
            Specialties=special_details[n].text
            Specialties=(Specialties.replace("\n","")).replace("  ","")
            data[10]=Specialties

        if headings0[n].text=='Education':
            Education=special_details[n].text
            Education=((Education.replace("      \n       "," and")).replace("\n","")).replace("  ","")
            data[11]=Education

    print(data)
    afaq=[data]
    csvfile = open('output3.csv', 'a')
    for row in afaq:
        #line = ','.join(row)
        values = ','.join(str(v) for v in row)
        csvfile.write(values + '\n')
# Out:
# 423
# ['Dr Harry A Insko', u'General Practice', u'(813) 855-4269', u'office@oldsmardentistry.com', u'www.OldsmarDentistry.com', '34677-3205', 'FL', 'Rd Oldsmar', '4050 Tampa', u'Male', u'General Practice', u'Meharry Medical College', 'https://findadentist.ada.org//303544/1644049/Find-a-Dentist-Oldsmar-Dr-Harry-A-Insko-General-Practice']
# 424
# ['Dr Thomas F Yoho', u'General Practice', u'(813) 623-1014', u'broadwaydentistry@gmail.com', u'www.tampabroadwaydental.com', '33619-2813', 'FL', 'Ave Tampa', '5811 E Broadway', u'Male', u'General Practice', u'West Virginia University', 'https://findadentist.ada.org//304581/2761270/Find-a-Dentist-Tampa-Dr-Thomas-F-Yoho-General-Practice']
# 425
# ...

# %%
import re
#reg = re.compile(".*?(\(?\d{3})? ?[\.-]? ?\d{3} ?[\.-]? ?\d{4}).*?", re.S)
phone_number=re.findall("\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4}", linkdetails[0].text, flags=re.IGNORECASE)
if len(phone_number)>0:
    print(phone_number)
# Out:
# [u'(727) 822-3314']

# %%
data=['-']*13
print(data)
afaq=[data]
csvfile = open('output3.csv', 'a')
for row in afaq:
    #line = ','.join(row)
    values = ','.join(str(v) for v in row)
    csvfile.write(values + '\n')
# Out:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']

# %%
aaa=linkdetails[0].text
aaa
# Out:
# u'(727) 822-3314'

# %%
afaq=[list3]
csvfile = open('output2.csv', 'a')
for row in afaq:
    #line = ','.join(row)
    values = ','.join(str(v) for v in row)
    csvfile.write(values + '\n')

# %%
list1=[]
p=0
with open(r'forsort.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        #list1.append(row[0:1])
        #print(row[7:9])
        list6 = ['-']*14
        lists1=row[7:8]
        lists2=row[8:9]
        listsa=lists2+lists1
        nametotal=' '.join(listsa)
        print nametotal
        if ('Ste') in nametotal:
            af=nametotal.split()
            for j in range(0,len(af)):
                if af[j]== 'Ste':
                    address0= ' '.join(af[0:j+2])
                    city0=' '.join(af[j+2:len(af)])
                    print(address0,city0)
                    list6[7]=address0
                    list6[8]=city0
            p=p+1
        else:
            afq=nametotal.split()
            city1=(afq[-1])
            address1=' '.join(afq[0:-1])
            print(address1,city1,'-')
            list6[7]=address1
            list6[8]=city1
            
            
        
        list6[0]=row[0:1][0]
        list6[1]=row[1:2][0]
        list6[2]=row[2:3][0]
        list6[3]=row[3:4][0]
        list6[4]=row[4:5][0]
        list6[5]=row[5:6][0]
        list6[6]=row[6:7][0]
        
        list6[9]=row[9:10][0]
        list6[10]=row[10:11][0]
        list6[11]=row[11:12][0]
        list6[12]=row[12:13][0]
        
        print(list6)
        print(list6)
        afaq=[list6]
        csvfile = open('o2.csv', 'a')
        for row in afaq:
            #line = ','.join(row)
            values = ','.join(str(v) for v in row)
            csvfile.write(values + '\n')
# Out:
# Address City Area
# ('Address City', 'Area', '-')
# ['Name', 'Specialties', 'Phone', 'Email', 'Website', 'Zip code', 'Region', 'Address City', 'Area', 'Gender', 'Specialties Details', 'Education', 'Website link', '-']
# ['Name', 'Specialties', 'Phone', 'Email', 'Website', 'Zip code', 'Region', 'Address City', 'Area', 'Gender', 'Specialties Details', 'Education', 'Website link', '-']
# 111 2nd Ave NE Ste 1104 Saint Petersburg
# ('111 2nd Ave NE Ste 1104', 'Saint Petersburg')
# ['Dr Kimberley D Daxon', 'Prosthodontics', '(727) 282-1970', 'info@daxtondentistry.com', 'www.daxtondentistry.com', '33701-3443', 'FL', '111 2nd Ave NE Ste 1104', 'Saint Petersburg', 'Female', 'Prosthodontics', 'CA-University Medical Center and University of North Carolina Chapel Hill', 'https://findadentist.ada.org//304565/1645070/Find-a-Dentist-Saint-Petersburg-Dr-Kimberley-D-Daxon-Prosthodontics', '-']
# ...

# %%
del list1[0]
len(list1)

# %%
nametotal='1906 59th St W Ste G Bradenton'

# %%
if ('Ste') in nametotal:
    af=nametotal.split()
    for j in range(0,len(af)):
        if af[j]== 'Ste':
            address0= ' '.join(af[0:j+2])
            city0=' '.join(af[j+2:len(af)])
            print(address0,city0)
# Out:
# ('1906 59th St W Ste G', 'Bradenton')

# %%
row[12:13][0]
# Out:
# 'https://findadentist.ada.org//314476/3504945/Find-a-Dentist-Tampa-Dr-Elliot-D-Dibbs-General-Practice'
