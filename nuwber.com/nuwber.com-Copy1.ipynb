# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import csv
from random import randint
import json, io
import random

from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import warnings
from openpyxl import Workbook

driver = webdriver.Chrome(executable_path=r'/Users/Name/Downloads/Compressed/chromedrives/chromedriver.exe')

# %%
driver.get("https://nuwber.com/")

# %%
from openpyxl import load_workbook
import requests.api
import warnings
from openpyxl import Workbook

# %%
list0=[]
wb = load_workbook(filename='80EM_NEW_RMS01.xlsx', read_only=True)
ws = wb['Sheet']
for row in ws.rows:
#       list0.append([row[0].value,row[1].value,row[2].value,row[3].value,row[4].value,row[5].value,row[6].value,row[7].value,row[8].value,row[9].value,row[10].value,row[11].value,row[12].value,row[13].value,row[14].value,row[15].value,row[16].value,row[17].value,row[18].value,row[19].value,row[20].value,row[21].value,row[22].value,row[23].value,row[24].value,row[25].value,row[26].value,row[27].value,row[28].value,row[29].value,row[30].value,row[31].value,row[32].value,row[33].value,row[34].value,row[35].value,row[36].value,row[37].value,row[38].value,row[39].value])
    list00=[]
    for kl in range(len(row)):
        
        list00.append(row[kl].value)
    list0.append(list00)

# %%
list0[0][41]

# %%
print (list0[0][2])
print (list0[0][3])
print (list0[0][5])
print (list0[0][6])
# Out:
# Owner1FName
# Owner1LName
# Owner2FName
# Owner2LName

# %%
print (list0[0][19])
print (list0[0][20])
# Out:
# PCity
# PState

# %%
for i in range(21,len(list0)):#len(list0)):
    print (list0[i][2]+' '+list0[i][3])
    print (list0[i][19]+', '+list0[i][20])
    
    name=driver.find_element_by_id('search_name1')
    name.send_keys(list0[i][2]+' '+list0[i][3])
    state=driver.find_element_by_id('search_state1')
    state.send_keys(list0[i][19]+', '+list0[i][20])
    sleep(random.randint(1,5))
    driver.find_elements_by_tag_name('button')[0].click()
    sleep(random.randint(1,5))    
    so0=BeautifulSoup(driver.page_source, 'lxml')
    
    persons0=so0.find_all('div',class_="search__best_block")
    if len(persons0)>0:
        persons1=persons0[0].find_all('a',href=True)
        if len(persons1)>0:
            hrefto=persons1[0].get('href')
            prelink0='https://nuwber.com'
            prelink=prelink0+hrefto
            print (prelink)
            list1=[]
            list1.append(prelink)
            list0[i]=list0[i]+list1
    driver.back()
            
    
    if list0[i][4] is not None:
        if list0[i][5] is not None:
            print (list0[i][5]+' '+list0[i][6])
            print (list0[i][19]+', '+list0[i][20])
            
            
            name=driver.find_element_by_id('search_name1')
            name.send_keys(list0[i][5]+' '+list0[i][6])
            state=driver.find_element_by_id('search_state1')
            state.send_keys(list0[i][19]+', '+list0[i][20])
            sleep(random.randint(1,5))
            driver.find_elements_by_tag_name('button')[0].click()
            sleep(random.randint(1,5))    
            so0=BeautifulSoup(driver.page_source, 'lxml')

            persons0=so0.find_all('div',class_="search__best_block")
            if len(persons0)>0:
                persons1=persons0[0].find_all('a',href=True)
                if len(persons1)>0:
                    hrefto=persons1[0].get('href')
                    prelink0='https://nuwber.com'
                    prelink=prelink0+hrefto
                    print (prelink)
                    list1=[]
                    list1.append(prelink)
                    list0[i]=list0[i]+list1
            driver.back()
    print (i)
# Out:
# Vivian Hardy
# Oakland, CA
# https://nuwber.com/person/563a4e167686b0176bdc73fb
# 21
# Early Davis
# Oakland, CA
# https://nuwber.com/person/563a59d87686b0176b27e042
# 22
# Douglas Clark
# Oakland, CA
# https://nuwber.com/person/563a4e187686b0176bdc822f
# 23
# Anamaria Morlino
# Oakland, CA
# 24
# Betty Lockett
# Oakland, CA
# https://nuwber.com/person/563a36047686b0176b3e4bc2
# 25
# Ronald Ghiselli
# San Lorenzo, CA
# https://nuwber.com/person/563a201e7686b0176bcd5ae9
# 26
# Bertha Lopez
# San Lorenzo, CA
# https://nuwber.com/person/563a201f7686b0176bcd5b85
# 27
# Juan Velasquez
# San Lorenzo, CA
# https://nuwber.com/person/563a201c7686b0176bcd508e
# 28
# Sharon Trueworthy
# San Lorenzo, CA
# https://nuwber.com/person/563a20207686b0176bcd6324
# 29
# Guang Lu
# San Lorenzo, CA
# 30
# Joseph Dazhan
# San Lorenzo, CA
# 31
# Lynn Bretchel
# Hayward, CA
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-23-35d166d4db08> in <module>()
#       3     print (list0[i][19]+', '+list0[i][20])
#       4
# ----> 5     name=driver.find_element_by_id('search_name1')
#       6     name.send_keys(list0[i][2]+' '+list0[i][3])
#       7     state=driver.find_element_by_id('search_state1')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     357             element = driver.find_element_by_id('foo')
#     358         """
# --> 359         return self.find_element(by=By.ID, value=id_)
#     360
#     361     def find_elements_by_id(self, id_):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#     968     def find_elements(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"id","selector":"search_name1"}
#   (Session info: chrome=67.0.3396.99)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.17134 x86_64)

# %%
driver.back()

# %%
wb = Workbook(write_only=True)
ws = wb.create_sheet()

# now we'll fill it with 100 rows x 200 columns
for irow in list0:
    ws.append(irow)
# save the file
wb.save('71_EM_Jumbo_THINK_INK0.xlsx')

# %%
if list0[1][40] is not None:
    print ('a')
# Out:
# a

# %%
list0=[]
wb = load_workbook(filename='90EM_NEW_JUMBO_RM_FIXED30own2.xlsx', read_only=True)
ws = wb['Sheet']
for row in ws.rows:
#       list0.append([row[0].value,row[1].value,row[2].value,row[3].value,row[4].value,row[5].value,row[6].value,row[7].value,row[8].value,row[9].value,row[10].value,row[11].value,row[12].value,row[13].value,row[14].value,row[15].value,row[16].value,row[17].value,row[18].value,row[19].value,row[20].value,row[21].value,row[22].value,row[23].value,row[24].value,row[25].value,row[26].value,row[27].value,row[28].value,row[29].value,row[30].value,row[31].value,row[32].value,row[33].value,row[34].value,row[35].value,row[36].value,row[37].value,row[38].value,row[39].value])
    list00=[]
    for kl in range(len(row)):
        
        list00.append(row[kl].value)
    list0.append(list00)

# %%
i
# Out:
# 1705

# %%
for i in range(1706,2731):
    listas=['-']*15
    listsa=['-']*15
    try:
        if list0[i][141] is not None:
            if 'https' in list0[i][141]:            
                driver.get(list0[i][141])
                sleep(5)
                so1=BeautifulSoup(driver.page_source, 'lxml')
                inner_text_phone=so1.find_all('div',class_="content__block_inner_item")
                listem=[]
                if inner_text_phone is not None:
                    for hg in range(len(inner_text_phone)):
                        if inner_text_phone[hg].find('span').text=='Email':
                            text_mail=inner_text_phone[hg].find_all('p',class_="inner_text inner_text_phone")

                            for mn in range(len(text_mail)):
                                emailid=((text_mail[mn].text).replace('\n','')).replace('  ','')
                                print (emailid)
                                listem.append(emailid)
                resp_cell=so1.find_all('div',class_="resp_cell resp_cell3")
                listph=[]
                for nb in range(len(resp_cell)):
                    resp_cell1=resp_cell[nb].find_all('p')
                    phones=((resp_cell1[1].text).replace('\n','')).replace('  ','')
                    print (phones)
                    listph.append(phones)
                if len(listem)>15:
                    while(len(listem)>15):
                        del listem[-1]
                    print ('list shorted=========')
                if len(listph)>15:
                    while(len(listph)>15):
                        del listph[-1]
                    print ('list shorted++++++++++')

                for mk in range(len(listem)):
                    listas[mk]=listem[mk]
                for nk in range(len(listph)):
                    listsa[nk]=listph[nk]
                list0[i]=list0[i]+listsa
                list0[i]=list0[i]+listas
        print(i)
    except:
        pass
# Out:
# rrudd@gmail.com
# (818) 249-2601
# (818) 261-5185
# (818) 352-5028
# (818) 249-9412
# (818) 353-9480
# (818) 261-5185
# (818) 249-2601
# 1706
# 1707
# martineaujames@hotmail.com
# jmartineau@peoplepc.com
# john.martineau@ix.netcom.com
# (413) 863-2811
# (970) 390-6467
# (413) 863-2811
# (802) 503-5567
# 1708
# (520) 868-1038
# (480) 882-9563
# 1709
# (562) 303-7443
# (562) 673-9321
# 1710
# sales@national-cleaners.com
# r.galvan@national-cleaners.com
# avelinag@hotmail.com
# (562) 595-6245
# (562) 595-6245
# (562) 927-3204
# (310) 927-3204
# 1711
# (562) 431-1141
# 1713
# (562) 598-5138
# 1715
# (562) 433-4560
# (562) 528-6038
# (562) 528-6038
# (562) 433-4560
# (310) 433-4560
# (562) 434-1092
# 1717
# (562) 434-2806
# 1719
# (770) 493-7425
# 1720
# (423) 246-3048
# 1724
# craig.gillett@juno.com
# rgillette@address.com
# cgillette@centurytel.net
# craigg1006@aol.com
# farnaz121@hotmail.com
# craiggillett@pacbell.net
# (217) 412-9433
# (217) 607-2052
# (512) 401-3016
# (504) 366-9365
# (504) 488-2492
# (504) 899-5958
# (256) 721-7030
# (318) 797-6228
# (281) 852-9166
# (225) 355-5292
# 1725
# 1729
# claireb3@aol.com
# claireb512@geocities.com
# claireb@geocities.com
# claireb512@verizon.net
# claireb512@juno.com
# claireb512@aol.com
# claireb@juno.com
# claireb512@bellsouth.net
# claireb@verizon.net
# claireb@bellsouth.net
# claireb2@aol.com
# (310) 547-1031
# (310) 547-1031
# (310) 519-8684
# 1732
# (513) 467-0117
# 1733
# (310) 377-8349
# (310) 292-1670
# grant_nowell@affymetrix.com
# tracey.nowell@hotmail.com
# (408) 448-1940
# (408) 221-3055
# (408) 448-1940
# (408) 221-3055
# (408) 557-9939
# 2088
# (408) 979-1704
# 2089
# (408) 268-4316
# (408) 391-0384
# (408) 268-4396
# 2093
# lourdesf@netzero.net
# lrfelix@aol.com
# luz.felix@gmail.com
# lourdesfelix@erols.com
# lrfelix@gmail.com
# felix@msn.com
# (408) 489-0282
# (408) 272-2056
# (408) 272-2056
# (626) 818-7167
# (408) 464-3389
# (408) 802-2786
# (408) 272-9568
# (408) 258-7019
# (408) 489-0282
# 2094
# (408) 309-2932
# (408) 272-3884
# 2095
# (408) 997-1010
# 2097
# (408) 927-0331
# (408) 425-2635
# (408) 927-0331
# (408) 425-2635
# 2098
# lindaquon@hotmail.com
# (408) 365-8176
# 2099
# janetj@cox.net
# (408) 732-3397
# (408) 887-3003
# (408) 421-5766
# 2100
# (408) 842-9932
# 2101
# bjamstutz@verizon.net
# (408) 842-2316
# (831) 636-5994
# (408) 842-2316
# (408) 848-1524
# (408) 248-6779
# (408) 636-5994
# (408) 848-1323
# (408) 847-0904
# (408) 847-1291
# 2102
# (831) 464-8861
# 2105
# grammer.beverly@bellsouth.net
# (831) 763-2910
# (217) 285-6366
# (217) 725-9511
# (217) 285-5660
# (217) 734-2041
# (217) 734-2719
# (217) 734-9246
# 2107
# (831) 688-0733
# 2108
# nicole@vacavillefruit.com
# billing@vacavillefruit.com
# nicoleciarabellini@netzero.net
# esqmost@aol.com
# (707) 864-8441
# (707) 864-8441
# (707) 864-1688
# (209) 275-8344
# (510) 275-8344
# (559) 275-8344
# (707) 448-8754
# (707) 864-2441
# (707) 448-5292
# (510) 222-9031
# 2109
# ipreciado@gmail.com
# imeldapreciado@netscape.net
# (707) 486-7480
# (707) 552-0176
# (707) 644-7034
# (707) 693-9890
# (707) 644-1498
# (707) 645-9896
# 2110
# (707) 578-1307
# 2113
# (707) 874-3332
# 2115
# (707) 938-3468
# 2116
# (707) 537-9682
# (707) 537-9682
# (707) 965-3523
# 2118
# (805) 484-1303
# (805) 484-1303
# 2120
# (805) 886-8102
# 2124
# (626) 387-9830
# (805) 582-1039
# (805) 527-3033
# 2128
# arlenehuelsen@geocities.com
# (805) 496-7202
# (805) 496-7202
# (805) 496-2020
# 2129
# robert@teck.net
# paulsonrobert85@yahoo.com
# (805) 494-1492
# (805) 660-8962
# (805) 660-8962
# (310) 391-5251
# (310) 706-8628
# (805) 494-1492
# 2132
# (805) 379-9191
# (805) 379-0755
# 2133

# %%
if list0[i][141]:
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-a65d539c5933> in <module>()
# ----> 1 if list0[i][141]:
#       2     print 'yes'
#
# IndexError: list index out of range

# %%
list0[i][111]
# Out:
# 23359136

# %%
len(listph)
# Out:
# 16

# %%
wb = Workbook(write_only=True)
ws = wb.create_sheet()

# now we'll fill it with 100 rows x 200 columns
for irow in list0:
    ws.append(irow)
# save the file
wb.save('90EM_NEW_JUMBO_RM_FIXED30own20.xlsx')

# %%
driver.back()
