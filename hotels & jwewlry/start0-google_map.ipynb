# %%
from openpyxl import load_workbook
import requests.api
import warnings
from openpyxl import Workbook
import random

# %%
list0=[]
wb = load_workbook(filename='0. DATA MINING JOB - SHORT.xlsx', read_only=True)
ws = wb['JEWELERS INFO']
for row in ws.rows:
    list00=[]
    for kl in range(len(row)):
        
        list00.append(row[kl].value)
    list0.append(list00)

# %%
list0[1][0]+' '+list0[1][1]
# Out:
# u'AMA St. Maarten '

# %%
import googlemaps
from time import sleep

g_maps=googlemaps.Client(key='#########')

# %%
place_ids1=[]
len(list0)
# Out:
# 169

# %%
place_ids0
# Out:
# [u'ChIJmctnaH_HBIwRcLOtdunbn8Y', u'W Retreat & Spa', u'Vieques, PR']

# %%
for mn in range(143,len(list0)):
    
    data0=g_maps.places(list0[mn][0]+' '+list0[mn][1])
    sleep(3)
    for i in  range(0,len(data0['results'])):
        place_ids0=[]
        print(data0['results'][i]['place_id'])
        place_ids0.append(data0['results'][i]['place_id'])
        place_ids0.append(list0[mn][0])
        place_ids0.append(list0[mn][1])
        
        place_ids1.append(place_ids0)
# Out:
# ChIJ1R1Me3FuDowR0mUSKKakdxU
# ChIJ5wDU1Zk4hY4RQZs7t0oLx5c
# ChIJD7CpcXFuDowRK8_la5VrS1E
# ChIJx6rcCJIaBYwRc7L0bJznxkM
# ChIJS0BZWPIbEowRyQZr5-uSoY4
# ChIJr_UMGIlHhY4Rymi84L4P9GM
# ChIJqzFrUPIaBYwRvZ1_wV7HV1s
# ChIJqzFrUPIaBYwRvZ1_wV7HV1s
# ChIJIZriVXBuDowRKoUQu44YTK8
# ChIJ1-CoLO04hY4RPeA8CFFT7OE
# ChIJv0z3knNuDowRGMd0KR_yu_s
# ChIJHR3Pr5k4hY4RgwtmLsk8zTo
# ChIJabAILRwVA4wRxy21fsVbp64
# ChIJX8D-1B0VA4wRFx9kXQ_sa7M
# ChIJ7zibMsFuA4wRl9m9hWr7rS8
# ChIJa95sYVZbA4wRs54HRBRUVD4
# ChIJE8eoG8ZrA4wRYI_bmiLVTpY
# ChIJYzahPMduA4wR2MseF1Exmrg
# ChIJRVYgtzVqA4wRANNp5a82_Cg
# ChIJq18tG8duA4wRo6BjieVVUEg
# ChIJQciA4rRhA4wRD5dvWqkQZq8
# ChIJxzd6n7huA4wRZ7yHjsFTsiw
# ChIJnwkTZfrVHIwROoK2ITosfcQ
# ChIJwy5MqzgfA4wRLJncjwhLSS8
# ChIJwy5MqzgfA4wRLJncjwhLSS8
# ChIJe3N31G0ULYoRzrdxNaoSWkQ
# ChIJnXBQsWwULYoR47EKxPvQPYs
# ChIJiZna4iVtLYoRF9AcljmseyU
# ChIJrU--Bx9tLYoRGjveKUhnf1o
# ChIJ9ydQnCRtLYoRPLAQl5r5l_E
# ChIJi7mzeyFtLYoRZVYSuD1JIfk
# ChIJR9eQQiRtLYoR5ydkRIV2Coo
# ChIJxU7l4RoTLYoREDEcbFfLV88
# ...

# %%
mn
# Out:
# 168

# %%
from openpyxl import Workbook

wb = Workbook(write_only=True)
ws = wb.create_sheet()

# now we'll fill it with 100 rows x 200 columns
for irow in place_ids1:
    ws.append(irow)
# save the file
wb.save('JEWELERS_googlekey.xlsx')

# %%
len(place_ids1)
# Out:
# 319

# %%
print(len(place_ids1))
from collections import OrderedDict
list_sor=list(OrderedDict.fromkeys(place_ids1))
list_sor
# Out:
# 591
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f6e7c8990de9> in <module>()
#       1 print(len(place_ids1))
#       2 from collections import OrderedDict
# ----> 3 list_sor=list(OrderedDict.fromkeys(place_ids1))
#       4 list_sor
#
# C:\ProgramData\Anaconda2\lib\collections.pyc in fromkeys(cls, iterable, value)
#     214         self = cls()
#     215         for key in iterable:
# --> 216             self[key] = value
#     217         return self
#     218
#
# C:\ProgramData\Anaconda2\lib\collections.pyc in __setitem__(self, key, value, dict_setitem)
#      73         # Setting a new item creates a new link at the end of the linked list,
#      74         # and the inherited dictionary is updated with the new key/value pair.
# ---> 75         if key not in self:
#      76             root = self.__root
#      77             last = root[0]
#
# ...

# %%
main_data_set0=[]
# Out:
# []

# %%
place_ids1[0][0]
# Out:
# u'ChIJM1KyeExpDowRtDWbGFX7iMU'

# %%
new_key='AIzaSyBTjcL3K5OWCmoZKA1Ym_Fgwd_t_SvW2E8'

# %%
import requests
import json
import urllib
import time

url0='https://maps.googleapis.com/maps/api/place/details/json?placeid='
url1='&fields=name,website,formatted_address,formatted_phone_number&key=AIzaSyCGtnXHSeVWXR6Bo7fp-bTaFri_u-htGyk'
for z in range(0,len(place_ids1)): #len(list_sor)
    data=['-']*6
    print(z)
    url=url0+place_ids1[z][0]+url1
    page=requests.get(url)
    time.sleep(5)
    j=json.loads(page.text)
    name=j['result']['name']
#     name=(name.replace(",","  ")).encode('ascii', 'ignore')
    data[0]=name
    if 'formatted_phone_number' in j['result']:
        formatted_phone_number=j['result']['formatted_phone_number']
        data[1]=formatted_phone_number
    if 'website' in j['result']:
        website=j['result']['website']
        data[2]=website
    if 'formatted_address' in j['result']:
        formatted_address=j['result']['formatted_address']
        data[3]=(formatted_address)    #.replace(",","  ")).encode('ascii', 'ignore')
    data[4]=place_ids1[z][1]
    data[5]=place_ids1[z][2]
    print data
    print'--------------------'
    main_data_set0.append(data)
# Out:
# 0
# [u'AMA Jewellers', u'(721) 546-7751', '-', u'Princess Juliana Airport, Simpson Bay, Sint Maarten', u'AMA', u'St. Maarten ']
# --------------------
# 1
# [u'AMA Jewellers & AMA Bella', u'(721) 542-1850', '-', u'24, Voorstraat, Philipsburg, Sint Maarten', u'AMA', u'St. Maarten ']
# --------------------
# 2
# [u'Ballerina Jewelers', u'(721) 542-4399', u'http://www.ballerina-jewelers.com/', u'Voorstraat, Philipsburg, Sint Maarten', u'Ballerina ', u'St. Maarten ']
# --------------------
# 3
# [u'Ballerina Jewelers', u'(340) 776-3701', u'http://www.ballerina-jewelers.com/', u'5180 Dronningens Gade Ste. 3, St. Thomas, VI 00802, USVI', u'Ballerina ', u'St. Thomas']
# --------------------
# 4
# [u'Ballerina Jewelers', u'(340) 776-3701', u'http://www.ballerina-jewelers.com/', u'5180 Dronningens Gade Ste. 3, St. Thomas, VI 00802, USVI', u'Ballerina ', u'St. Thomas ']
# --------------------
# 5
# ...

# %%
from openpyxl import Workbook

wb = Workbook(write_only=True)
ws = wb.create_sheet()

# now we'll fill it with 100 rows x 200 columns
for irow in main_data_set0:
    ws.append(irow)
# save the file
wb.save('JEWELERS_out0.xlsx')
