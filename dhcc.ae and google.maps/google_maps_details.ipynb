# %%
import csv
import requests
import json
import urllib
import time

# %%
list1=[]
with open('first1.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(row)
        #list1.append(row[1:2]) #fill it in a list with the column that contains website urls
# Out:
# ['Mediclinic City Hospital', 'Building # 37  Dubai Health Care City - Dubai - United Arab Emirates', '25.2304161', '55.3226213', '3.5', 'ChIJAVqxKjZdXz4R4v9FCSj5bTg']
# ['Dr. Sulaiman Al Habib Hospital', 'Building 57 - Dubai Healthcare City - Umm Hurair 2 - Dubai - United Arab Emirates', '25.2324309', '55.3209793', '4.2', 'ChIJ___PWjZdXz4RwACWbciswlo']
# ['asd &European University College', 'Building 27    3rd Floor - 4 26th St - Dubai - United Arab Emirates', '25.2313507', '55.325759', '3', 'ChIJDfC8BjhdXz4RsuaHfwVO1og']
# ['BR Medical Suites', '4th Floor   4005   Building 64   Block B   Dubai Health Care City - Dubai - United Arab Emirates', '25.233413', '55.318006', '4.1', 'ChIJY0SVdTRdXz4RNLCQfS1pWFA']
# ["Al Jalila Children's Specialty Hospital", 'Al Jaddaf - Dubai - United Arab Emirates', '25.2255527', '55.3189646', '4.1', 'ChIJEfIHR0ldXz4R04nWpljpSSI']
# ...

# %%
listh=[]
with open('first1.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        listh.append(row)

# %%
url0='https://maps.googleapis.com/maps/api/place/details/json?placeid='
url1='&fields=name,website,formatted_phone_number&key=AIzaSyCGtnXHSeVWXR6Bo7fp-bTaFri_u-htGyk'
for i in range(195,196):
        data=['null']*8
        place_id=listh[i][5]
        url=url0+place_id+url1
        page=requests.get(url)
        time.sleep(5)
        j=json.loads(page.text)
        name=listh[i][0]
        data[1]=name
        address=listh[i][1]
        data[2]=address
        lat=listh[i][2]
        data[3]=lat
        lng=listh[i][3]
        data[4]=lng
        rating=listh[i][4]
        data[5]=rating

        if 'formatted_phone_number' in j['result']:
            formatted_phone_number=j['result']['formatted_phone_number']
            data[6]=formatted_phone_number
        if 'website' in j['result']:
            website=j['result']['website']
            data[7]=website
        
        print(data)
        afaq=[data]
        csvfile = open('second1.csv', 'a')
        for row in afaq:
            #line = ','.join(row)
            values = ','.join(str(v) for v in row)
            csvfile.write(values + '\n')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-c5371de5c256> in <module>()
#       3 for i in range(195,196):
#       4         data=['null']*8
# ----> 5         place_id=listh[i][5]
#       6         url=url0+place_id+url1
#       7         page=requests.get(url)
#
# IndexError: list index out of range

# %%
afaq=[save]
csvfile = open('first0.csv', 'a')
for row in afaq:
    #line = ','.join(row)
    values = ','.join(str(v) for v in row)
    csvfile.write(values + '\n')
# Out:
# 195

# %%
place_id=row[5:6][0]
url=url0+place_id+url1
#page=requests.get(url)
csvfile.closed
# Out:
# True
