# %%
import re
import urllib
import urllib3
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import csv
from random import randint
urllib3.disable_warnings()
import json, io
headers = {'User-Agent':'Mozilla/6.0'}

# %%
list1=[]
with open('first0.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(row)
        list1.append(row)
# Out:
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000328581&expo=SMI']
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000329663&expo=ARB']
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000224731&expo=CDA']
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000277426&expo=ARB']
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000010068&expo=SMI']
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000010081&expo=SMI']
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000015250&expo=SMI']
# ['https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000329917&expo=SMI']
# ...

# %%
print list1[0][0]
# Out:
# https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000328581&expo=SMI

# %%
"/espositori/catalogo-espositori/catalogo-contatta.html?id=0000328581&expo=SMI"
# Out:
# '/espositori/catalogo-espositori/catalogo-contatta.html?id=0000328581&expo=SMI'

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException

from time import sleep
import csv
from selenium import webdriver

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("user-agent=Mozilla/8.0")
driver = webdriver.Chrome(executable_path=r'/Users/Name/Downloads/Compressed/chromedrives/chromedriver.exe',chrome_options=chrome_options)

# %%
i
# Out:
# 1227

# %%
for i in range(978,978):
    driver.get(list1[i][0])
    sleep(2)
    driver.find_element_by_xpath('//*[@id="content-wrapper"]/section[2]/div/div/div/div[1]/a').click()
    sleep(3)
    
    title=driver.find_element_by_id('contact_expositor_subject')
    title.clear()
    sleep(1)
    title.send_keys('Partnership with Brasilian Wood Artigiano')
    
    name=driver.find_element_by_id('contact_expositor_name')
    name.clear()
    sleep(1)
    name.send_keys('David')
    
    surname=driver.find_element_by_id('contact_expositor_surname')
    surname.clear()
    sleep(1)
    surname.send_keys('Almeida')
    
    email=driver.find_element_by_id('contact_expositor_email')
    email.clear()
    email.send_keys('david@madeirado.com.br')
    sleep(1)
    
    messagetext='Mi chiamo David Almeida e sono il titolare dell’azienda Madeirado, con sede a San Paolo, Brasile. Ci occupiamo della lavorazione di mobili in legno brasiliano massello certificati secondo gli standard di riforestazione e certificati IBAMA (Ente Governativo Brasiliano che supervisiona questo settore). Siamo alla ricerca di aziende e professionisti in Italia che vogliano collaborare con noi, utilizzando le nostre radici e il nostro legno per le loro creazioni in vista del prossimo Salone del Mobile di Milano. Si tratta di pezzi unici ed esclusivi, molto differenti gli uni dagli altri, che, sono certo, professionisti del suo calibro sapranno sicuramente sfruttare al meglio. Qualora fosse interessato a una possibile collaborazione, le lascio i miei ricapiti dove potrà trovarmi sempre disponibile: david@madeirado.com.br / Instagram: @madeirado_decor. Link ad alcuni esempi di materie prime: https://www.madeirado.com.br/pages/italia.'
    messagetext=messagetext.decode('utf-8')
    message=driver.find_element_by_id('contact_expositor_message')
    message.clear()
    message.send_keys(messagetext)
    driver.find_elements_by_tag_name('button')[2].click()
    print i,'-----------'
# Out:
# 978 -----------
# 979 -----------

# %%
i
# Out:
# 1227

# %%
#https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000327649&expo=SMI
#https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000035808&expo=FTK
# https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000020711&expo=SMI
# https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000304854&expo=FTK
# https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000273751&expo=FTK
# https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000013916&expo=SMI
# https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000013916&expo=CDA
# https://www.salonemilano.it/espositori/catalogo-espositori/catalogo-dettaglio.html?id=0000329495&expo=SMI
#
