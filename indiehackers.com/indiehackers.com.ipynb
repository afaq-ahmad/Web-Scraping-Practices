# %%
'''
Devolper Name: AFAQ AHMAD
Fiverr: https://www.fiverr.com/mrafaq1
Whatssapp: +92-335695635
Email:afaq.ahmad100@gmail.com
'''
import re
import urllib
import urllib3
import requests
from bs4 import BeautifulSoup
urllib3.disable_warnings()
headers = {'User-Agent':'Mozilla/5.0'}

# %%
urlpage="https://www.walmart.com/browse/electronics/all-tvs/3944_1103592_1305089_447913?min_price=50&page=1&povid=1060825+%7C+2018-04-30+%7C+Shop+by+Category+TVs+by+Price#searchProductResult"
page = requests.get(urlpage, headers=headers, verify=False)
data = page.content 
soup = [BeautifulSoup(data, "html.parser")]

# %%
print(soup)
# Out:
# [<!DOCTYPE html>\n<html lang="en"><head><link href="fonts.walmart.com" rel="dns-prefetch"/><link href="beacons.walmart.com" rel="dns-prefetch"/><link href="i5.walmartimages.com" rel="dns-prefetch"/><meta charset="unicode-escape"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><link href="//www.google.com" rel="dns-prefetch"/><link href="//a14.wal.co" rel="dns-prefetch"/><link href="//i5.walmartimages.com" rel="dns-prefetch"/><link href="//beacon.walmart.com" rel="dns-prefetch"/><link href="//www.googletagservices.com" rel="dns-prefetch"/><link href="//b.wal.co" rel="dns-prefetch"/><link href="//tpc.googlesyndication.com" rel="dns-prefetch"/><link href="//partner.googleadservices.com" rel="dns-prefetch"/><link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/><link href="//p.typekit.net" rel="dns-prefetch"/><link href="//omniture.walmart.com" rel="dns-prefetch"/><link href="//omniture-ssl.walmart.com" rel="dns-prefetch"/><link href="//pubads.g.doubleclick.net"
# ...

# %%
tit1=soup[0].find_all('li', class_="podcast-index__episode")

# %%
print(tit1[0])
Class 4K Ultra HD (2160p) HDR Smart LED TV (49H6E)
Product TitleHisense 49" Class 4K Ultra HD (2160p) HDR Smart LED
# Out:
# <li class="podcast-index__episode" data-podcast-id="057-saron-yitbarek-of-codenewbie">
# <a class="ember-view" href="/podcast/057-saron-yitbarek-of-codenewbie" id="ember125112"> <div class="podcast-index__episode-thumbnail" style="background-image:url(https://storage.googleapis.com/indie-hackers.appspot.com/podcast-thumbnails/057-saron-yitbarek-of-codenewbie.jpg)"></div>
# <!-- --> <div class="podcast-index__episode-text">
# <h2>#057 – Wearing All the Hats as a Founder with Saron Yitbarek of CodeNewbie</h2>
# <p>Saron Yitbarek (@saronyitbarek) runs three podcasts, gives dozens of talks every year, runs a blog, a weekly Twitter chat, a conference, an online resource for teaching people to code, among other things. In this episode, Saron explains how she parlays her advantages in one arena to move into another, discusses her tips for being inhumanly productive, and discusses the psychological breakthrough that taught her when to say no to adding more work to her plate.</p>
# </div>
# ...

# %%
link0=tit1[1].find_all('a', href=True)
link1=link0[0].attrs['href']
link1
# Out:
# u'/podcast/056-quincy-larson-of-freecodecamp'

# %%
statement0=tit1[0].find('h2')
statement1=(statement0.text).encode('ascii', 'ignore')
statement1
# Out:
# '#057  Wearing All the Hats as a Founder with Saron Yitbarek of CodeNewbie'

# %%
link2='https://www.indiehackers.com'
link=link2+link1
link
# Out:
# u'https://www.indiehackers.com/podcast/056-quincy-larson-of-freecodecamp'

# %%
for i in range(0,len(tit1)):
    data=[0]*2
    link0=tit1[i].find_all('a', href=True)
    link1=link0[0].attrs['href']
    link2='https://www.indiehackers.com'
    link=link2+link1
    data[0]=link
    print(link)
    statement0=tit1[i].find('h2')
    statement1=(statement0.text).encode('ascii', 'ignore')
    statement=((statement1.replace(","," "))).encode('ascii', 'ignore')
    data[1]=statement
    
    afaq=[data]
    csvfile = open('outputre.csv', 'a')
    for row in afaq:
        #line = ','.join(row)
        values = ','.join(str(v) for v in row)
        csvfile.write(values + '\n')
# Out:
# https://www.indiehackers.com/podcast/057-saron-yitbarek-of-codenewbie
# https://www.indiehackers.com/podcast/056-quincy-larson-of-freecodecamp
# https://www.indiehackers.com/podcast/055-claire-lew-of-know-your-company
# https://www.indiehackers.com/podcast/054-vicky-hsu-of-habitica
# https://www.indiehackers.com/podcast/053-steli-efti-of-close-io
# https://www.indiehackers.com/podcast/052-tiffany-and-danny-of-remix
# https://www.indiehackers.com/podcast/051-rand-fishkin-of-moz-and-sparktoro
# https://www.indiehackers.com/podcast/050-katelyn-gleason-of-eligible
# https://www.indiehackers.com/podcast/049-josh-kaufman-of-the-personal-mba
# https://www.indiehackers.com/podcast/048-david-smooke-of-hacker-noon
# https://www.indiehackers.com/podcast/047-joel-runyon-of-impossible
# https://www.indiehackers.com/podcast/046-austen-allred-of-lambda-school
# https://www.indiehackers.com/podcast/045-max-lytvyn-of-grammarly
# https://www.indiehackers.com/podcast/044-stephanie-hurlburt-of-binomial
# ...

# %%
len(tit1)
# Out:
# 57

# %%
data
# Out:
# [u'https://www.indiehackers.com/podcast/001-jason-grishkoff-of-submithub',
#  '#001  Building an Audience and Being Scrappy with Jason Grishkoff of SubmitHub']
